# %% [markdown]
# ## EJERCICIO 10

# %% [markdown]
# ### Importaciones iniciales
# Ejecutar en primer lugar el siguiente código para importar los archivos que se utilizarán:

# %%
# Para importación de funciones, agregar la carpeta src al path si no está
import sys
if '../src' not in sys.path:
    sys.path.append('../src')

# Importo módulo de funciones
import game_functions

# Reload: usar para recargar archivo de funciones
import importlib
importlib.reload(game_functions)

# %% [markdown]
# ### Simulación de partidas y ranking en shooter online
# Simular varias partidas de un juego de disparos y generar un ranking basado en el puntaje total de cada jugador.
# Se utilizará el siguiente sistema de puntuación:
# - Kill = 3 puntos
# - Asistencia = 1 punto
# - Muerte = -1 puntos

# %%
# rounds: lista de diccionarios que representan las rondas del juego.
# Cada diccionario es una ronda, donde:
# - La clave es el nombre del jugador (str).
# - El valor es otro diccionario con las estadísticas del jugador:
#   * 'kills': Número de eliminaciones (int).
#   * 'assists': Número de asistencias (int).
#   * 'deaths': Si el jugador murió en la ronda (bool).
rounds = [
    {
        'Shadow': {'kills': 2, 'assists': 1, 'deaths': True},
        'Blaze': {'kills': 1, 'assists': 0, 'deaths': False},
        'Viper': {'kills': 1, 'assists': 2, 'deaths': True},
        'Frost': {'kills': 0, 'assists': 1, 'deaths': False},
        'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
    },
    {
        'Shadow': {'kills': 0, 'assists': 2, 'deaths': False},
        'Blaze': {'kills': 2, 'assists': 0, 'deaths': True},
        'Viper': {'kills': 1, 'assists': 1, 'deaths': False},
        'Frost': {'kills': 2, 'assists': 1, 'deaths': True},
        'Reaper': {'kills': 0, 'assists': 1, 'deaths': False}
    },
    {
        'Shadow': {'kills': 1, 'assists': 0, 'deaths': False},
        'Blaze': {'kills': 2, 'assists': 2, 'deaths': True},
        'Viper': {'kills': 1, 'assists': 1, 'deaths': True},
        'Frost': {'kills': 0, 'assists': 1, 'deaths': False},
        'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
    },
    {
        'Shadow': {'kills': 2, 'assists': 1, 'deaths': False},
        'Blaze': {'kills': 1, 'assists': 0, 'deaths': True},
        'Viper': {'kills': 0, 'assists': 2, 'deaths': False},
        'Frost': {'kills': 1, 'assists': 1, 'deaths': True},
        'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
    },
    {
        'Shadow': {'kills': 1, 'assists': 2, 'deaths': True},
        'Blaze': {'kills': 0, 'assists': 1, 'deaths': False},
        'Viper': {'kills': 2, 'assists': 0, 'deaths': True},
        'Frost': {'kills': 1, 'assists': 1, 'deaths': False},
        'Reaper': {'kills': 1, 'assists': 1, 'deaths': True}
    }
]

# stats: diccionario donde se acumularán las estadísticas totales de los jugadores.
# - La clave es el nombre del jugador (str).
# - El valor es otro diccionario con estadísticas acumuladas, incluyendo:
#   * 'kills': Eliminaciones totales (int).
#   * 'assists': Asistencias totales (int).
#   * 'deaths': Muertes totales (int).
#   * 'MVP': Cantidad de veces que fue MVP (int).
#   * 'points': Puntos totales acumulados en todas las rondas (int).
stats = {}
# mvp: variable que almacena el nombre del jugador con el mayor puntaje en cada ronda (str).
# - Si no se encuentra un MVP válido, será `None`.
mvp = None

print("Inicio de simulación de shooter online")
print("-" * 54)

# round_number: contador que rastrea el número actual de la ronda (int).
# Inicializado en 1 y se incrementa después de procesar cada ronda.
round_number = 1

# Si la lista rounds está vacía imprime mensaje
if not rounds:
    print("No hay datos para procesar")
    
# Itero sobre cada ronda en la lista rounds.
# round_data: Diccionario que contiene las estadísticas de los jugadores en la ronda actual.
else:   
    for round_data in rounds:
        # Actualizo las estadísticas acumuladas y busco el MVP
        mvp = game_functions.update_stats(round_data, stats)
        
        # imprimo los resultados de cada ronda
        # Los resultados se acumulan
        # Si la ronda es la última, imprime 'Ranking final'
        if round_number == len(rounds):
            print('Ranking final:')
            game_functions.print_ranking('Final', stats, mvp)
        else:
            print(f"Ranking ronda {round_number}:")
            game_functions.print_ranking(round_number, stats, mvp)
        
        print('\n')

        # Incremento el contador de rondas
        round_number += 1
